# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import re
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary


import time
import sys

# %%
def filterWords(words):
    newWords = []
    for word in words:
        word = word.lower()
        word = word.replace("!", "")
        word = word.replace("?", "")
        word = word.replace(":", "")
        word = word.replace(";", "")
        word = word.replace(".", "")
        word = word.replace(",", "")
        word = word.replace('\'', "")
        word = word.replace('\"', "")
        #words below are ones where we want to connect together to ensure these words are joined
        word = word.replace("trumps", "trump")
        word = word.replace("russian", "russia")
        word = word.replace("russians", "russia")
        word = word.replace("dems", "democrat")
        word = word.replace("democrats", "democrat")
        word = word.replace("republicans", "republican")
        word = word.replace("libs", "liberal")
        word = word.replace("liberals", "liberal")
        word = word.replace("conservatives", "conservative")
        word = word.replace("taxes", "tax")
        word = word.replace("socialists", "socialist")
        word = word.replace("nationalists", "nationalist")
        word = word.replace("globalists", "globalist")
        word = word.replace("corrupted", "corrupt")
        newWords.append(word)
    return newWords

# %%
# Scrape Huffington (limited history = 15 pages --> 260 articles)
# Set up arrays 


def scrapeTest():
    articlesDF = []
    wordsDF = []
    for x in range (2, 15):
        url = 'https://www.huffingtonpost.com/section/politics?page=' + str(x)
#     article_title = []
#     article_URL = []
#     interaction_count = []
        html_doc = requests.get(url,  headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(html_doc.text, 'html.parser')

        articleList = soup.find('div', {'class': 'a-page__column--center'})
        articleList = articleList.find("div", {"class": "zone__content"})
        articles = articleList.findAll("div", {"class": "card"})
        
        print("______________________________")
        for article in articles:
                linkHTML = article.find("a", {"class": "card__link yr-card-headline"})
                link = linkHTML['href']
                linkURL = "https://www.huffingtonpost.com" + link
                articleTitle = article.find('div', {'class': 'card__headline__text'}).text
                articleTitle = articleTitle.replace('\n', '')
                wordsInTitle = articleTitle.split()
                wordsInTitle = filterWords(wordsInTitle)
                print(articleTitle)       
                html_docArticle = requests.get(linkURL,  headers={'User-Agent': 'Mozilla/5.0'})
                articleSoup = BeautifulSoup(html_docArticle.text, 'html.parser')
                socialMediaBar = articleSoup.find('ul', {'class': 'share-bar__list'})
                #print(socialMediaBar)
                #print(socialMediaBar)
                try:
                    socialMediaCount = socialMediaBar.find('span', {'class': 'share-bar__social-counts__number'}).text
                    if 'k' in socialMediaCount:
                        socialMediaCount = socialMediaCount.replace('k','')
                        try:
                            socialMediaCount = int(socialMediaCount) * 1000
                        except:
                            socialMediaCount = int(float(socialMediaCount) * 1000)
                    else:
                        socialMediaCount = int(socialMediaCount)
                    print(socialMediaCount)
                    articlesDF.append({'url': linkURL, 'articleTitle': articleTitle, 'socialMediaCount': socialMediaCount})
                    for word in wordsInTitle:
                        wordsDF.append({'url': linkURL, 'articleTitle': articleTitle, 'word': word,
                                        'socialMediaCount': socialMediaCount})
                except Exception as e:
                    print('Error on line {}'.format(sys.exc_info()[-1].tb_lineno), type(e).__name__, e)
                    #print("article has no social media count")
    return [articlesDF, wordsDF]
                    
#                 except:
#                     print("doesn't have socialMediaCount")
#                 print(" ")

# %%
dfs = scrapeTest()
# Out:
# ______________________________
# Stacey Abrams Says She’ll Run Again After Losing Fierce Battle For Georgia Governor
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Obama Photographer Taunts Trump With Doggone Funny Suggestion For Chief Of Staff
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# 44 Former Senators Warn Current Lawmakers Not To Blow It On Trump
# 630
# Trump Administration Paid Firm Nearly $14 Million For Just 2 New Recruits
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Anthony Scaramucci Is Still Bitter About Being Fired By John Kelly
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Jon Voight Appears Game To Be Trump's Chief Of Staff, And Hilarity Ensues
# 510
# Accused Russian Agent Maria Butina Reaches Plea Deal With Federal Prosecutors: Reports
# 2000
# Trump's Businesses Have Charged $1.1 Million To His Own Re-election Campaign: Forbes
# 3800
# Kevin McCarthy Says Democrats Shouldn't Spend A Lot Of Time Investigating Trump
# 5200
# FBI Announces Arrests Of 2 People Allegedly Plotting Separate Terror Attacks In Ohio
# 2900
# Ryan Zinke Puts Interior Department Loyalist In Charge Of Public Records Requests
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Protesters Arrested Outside Nancy Pelosi's Office In Climate Demonstration
# 240
# Republicans To Hold Their First Hearing On The Minimum Wage Since Taking The House In 2010
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Supreme Court Justices Won't Hear States' Appeal Over Planned Parenthood
# 260
# Beto O'Rourke Reportedly Spoke With Al Sharpton As 2020 Speculation Swirls
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# DNC Mandates Staff Neutrality In Presidential Primaries
# 540
# Air Force Missed 6 Chances To Prevent Texas Mass Shooter From Buying Guns
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Lame-Duck Power Grabs Escalate Unsettling Trend
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Eyes Four New Candidates For Chief Of Staff
# 410
# French Government Slams Trump: Stop Interfering And 'Leave Our Nation Be'
# 5400
# ______________________________
# Read James Comey's Testimony To The House Oversight Committee
# 1100
# Republicans Around The Country Are Working To Declare Democrats Unconstitutional
# 2900
# Rep. Joaquín Castro: If Trump Weren't President, 'He'd Be In Court Right Now'
# 1800
# A Look Back At John Kelly's Turbulent Time In The White House
# 500
# John Kelly Out As White House Chief Of Staff By End Of Year
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Democratic Women Are About To Lead Michigan. Republican Men Are Freaking Out.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Goes On All-Caps Twitter Rant About 'NO COLLUSION'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# A Prominent White Supremacist Is An EMT In Virginia. Now The State Is Investigating Him.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Picks Gen. Mark Milley As Next Top Military Adviser
# 170
# George Conway Fact-Checks Donald Trump's 'Totally Clears The President' Claim
# 3800
# President 'Individual-1' Trump Hasn't A Clue, But Twitter Wits Aim to School Him
# 3800
# More Evidence Of Illegal Activity Emerges In North Carolina Congressional Race
# 2800
# Here Are The Most Interesting Parts Of The Latest Mueller Filings
# 120
# NRA, Trump Campaign Illegally Coordinated Election Ads, Charges FEC Complaint
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Comey Rips Panels For Grilling Him On 'Whole Lotta' Clinton Emails, 'For Heaven's Sakes'
# 3500
# Ocasio-Cortez Claps Back At Trump Jr.’s Meme With Reminder Of Democrats’ Subpoena Power
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Robert Mueller Details Paul Manafort's Lies In Trump-Russia Probe
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Michael Cohen Acted 'At The Direction' Of Donald Trump, Federal Prosecutors Say
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Giuliani’s Report Will Hit All Of Trump’s Favorite Fox News Conspiracy Theory Villains
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Says He Is 'Totally' Cleared Following Michael Cohen Sentencing Recommendations
# 14000
# ______________________________
# Court Deadlines Set Stage For More Robert Mueller Russia Investigation Details
# 310
# Crime Bill Would Not Prevent Kids From Being Sentenced To Die In Prison, Advocates Say
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Announces William Barr As Attorney General Nominee
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Rages On Twitter Ahead Of Developments In Mueller Probe
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# If You Like Trump’s 'Wall,' Thank Obama And Bush. It’s Basically Just Their Fence.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Bernie Sanders Dings Donald Trump With 'Honest President' Tribute To George H.W. Bush
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Jr. Attacks Alexandria Ocasio-Cortez With Dog-Eating Meme
# 6000
# Donald Trump Becomes Butt Of Twitter Jokes With 'Boarder Security' Typo
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Fox Business Slams GOP Rep. Louie Gohmert For Anti-Soros Screed -- On Fox Business
# 260
# GOP Candidate's Consultant Linked To 2nd County In North Carolina Election Probe
# 290
# Boston Globe: Elizabeth Warren Should Reconsider 2020 Presidential Run
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Republican Rep. David Valadao Concedes To Democrat TJ Cox In California House Race
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Appoints State Department's Heather Nauert As U.S. Ambassador To United Nations
# 35000
# Democrat Dan McCready Retracts Concession Amid North Carolina Election Fraud Probe
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Rep. Ted Lieu: It's 'Too Late' For Trump To Shut Down The Russia Probe
# 610
# Joe Manchin Faces Opposition From Left Over Top Senate Committee Post
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Michigan Republicans Rush To Weaken Unions In Lame-Duck Session
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Gun Violence Has Cut More Than 4 Years Off The Life Expectancy Of Black Americans: Study
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Rudy Giuliani Calls Getting Trump Through Robert Mueller's Questions 'A Nightmare'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Supreme Court Double Jeopardy Case Looks Like Good News For Mueller Probe
# 100
# ______________________________
# Donald Trump Reportedly Shrugged Off Looming Debt Crisis Because 'I Won't Be Here'
# 130
# Finding Decent Child Care Is A Huge Struggle For Some Families, New Report Shows
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Amid North Carolina Election Probe, Voters Are Scared, Confused And Angry
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Seth Meyers Issues Scathing Warning About Mike Pence: 'As Slippery Of A Liar' As Trump
# 2100
# Joe Biden Blames Rise In Anti-Semitic Incidents Firmly On Donald Trump's Administration
# 920
# Michigan Officially Legalizes Marijuana For Recreational Use
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Alyssa Milano Rips Betsy DeVos' Campus Sexual Assault Rules In Dr. Seuss Spoof
# 700
# Trump Administration Is Turning Child Migrants Away At The Border, Lawyers Say
# 420
# Wisconsin Republicans Approve 82 Scott Walker Appointees In 1 Day
# 11000
# House Democratic Leader Nancy Pelosi Considers Term Limits On Committee Chairs
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Her Super PAC Ran A Racist Ad. Now She Runs West Virginia’s Minority Affairs Office.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Jonathan Van Ness Reminds People Of George H.W. Bush's AIDS Crisis Shortcomings
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trumps And Obamas Share Awkward, Tense Moment At George H.W. Bush Funeral
# 8000
# Utah's Hate Crime Law Is 'Unenforceable.' A Brutal Attack In Salt Lake City Could Change That.
# 240
# How The Michigan GOP Gutted A Minimum Wage Hike And Paid Sick Leave
# 2100
# Paul Ryan Silent On GOP Power Grab In Wisconsin
# 1600
# Republican Businessman Sheldon Lubar Calls Wisconsin Gov. Scott Walker 'Conniving'
# 1000
# In Stunning Power Grab, Wisconsin Republicans Pass Bill Weakening New Governor
# 20000
# Rudy Giuliani Goes Full Conspiracy Theorist Because He Doesn't Understand The Internet
# 6200
# Fox News Host Laura Ingraham Likens People Protesting Confederate Statues To ISIS
# 1000
# ______________________________
# Donald Trump Jr. Shared A Bonkers Christmas Meme Of His Dad
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Chris Cuomo's Eulogy For George H.W. Bush Serves As Scalding Takedown Of Trump
# 580
# Lawyers For Donald Trump Seek To Punish Stormy Daniels In Court Fines
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Florida SWAT Officer Demoted After Wearing QAnon Patch In Photo With Mike Pence
# 2800
# Arnold Schwarzenegger Goes After Trump On Climate: America Is More Than One 'Meshugge'
# 3100
# Bernie Sanders Stakes Out Forceful Climate Stance, Leapfrogging The 2020 Field
# 1700
# Midwestern Republicans Try To Kneecap New Democratic Governors
# 570
# Deported Parents Make Last-Ditch Effort To Reunite With Separated Kids In U.S.
# 470
# Hey, Ivanka Trump: You’ve Got The Wrong Definition Of ‘Human Trafficking’
# 610
# The Latest Photos From The Funeral Of President George H.W. Bush
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Wisconsin Republicans Advance Lame-Duck Power Grab
# 2200
# Evil Genius Turns Giuliani's Typo-Ridden Tweet Into Hilarious Anti-Trump Message
# 1300
# Elijah Cummings Wants Brian Kemp To Testify In Washington About Voter Suppression
# 4500
# Alexandria Ocasio-Cortez Tells Mike Huckabee To Leave 'False Statements To Sarah'
# 4400
# Congress Is Running Out Of Time To Pass Its Sexual Harassment Bill
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# George Conway Suggests New Donald Trump Tweet May Break The Law
# 1100
# The Kennedy Center Honors Didn't Need Donald Trump
# 220
# Running For Office Is Really Hard If You're Not A Millionaire
# 960
# Bernie Sanders Eyes 'Bigger' 2020 Presidential Run Despite Some Warning Signs
# 5300
# Barely Anyone Actually Fights About Politics Over Thanksgiving Dinner
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# ______________________________
# U.S. To Keep About 4,000 Troops At Border Through January
# 180
# Trump Starts New Week By Tweeting Up A Storm, Omitting Some Major Headlines
# 400
# Beto O'Rourke Condemns Use Of Tear Gas On Asylum Seekers At Border
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Cancels Meeting With Putin Amid Ukraine-Russia Conflicts
# 620
# American Killed On Remote Andaman And Nicobar Islands Off-Limits To Visitors
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Julian Assange Faces Federal Charges. But Let's Not Forget What We've Learned From WikiLeaks.
# 580
# John Paul Stevens, Retired Justice, Says He Left Supreme Court After Suffering Mini-Stroke
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Senate Panel Delays Vote On Trump's Pick To Lead ICE Over Tweet Critical Of President
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# This Asylum-Seeker Found A Community To Back Him. Now He Needs A Judge To Agree.
# 170
# Ohio State Coach Urban Meyer To Retire After Rose Bowl
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Giuliani Says Trump Doesn't Know If Paul Manafort Met With WikiLeaks’ Julian Assange
# 200
# GOP Rep. Bob Goodlatte: It's 'Awfully Tough' For Ivanka Trump To Comply With Email Rules
# 540
# Beto O'Rourke Won't Rule Out 2020 Presidential Run
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Slams CNN Again On Twitter, Proposes 'Starting Our Own Worldwide Network'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# More Than A Year Post-Maria, Puerto Rico's Governor Beseeches Congress For Help
# 650
# Texas Republicans Want To Oust Muslim Party Leader Because Of His Faith, Emails Suggest
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Sen. Cindy Hyde-Smith Is A 'White Supremacist,' Says Mississippi Rhodes Scholar
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Threatens To Cut 'All GM Subsidies' Following Company Layoffs
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# MLB Asks Cindy Hyde-Smith Campaign To Return $5,000 Donation: Report
# 1100
# Trump Vs The World: G-20 Summit Stumbles On Trade, Climate
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# ______________________________
# Cindy Hyde-Smith Proves Gender Equality Alone Isn’t Enough For Progress
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Ivanka Trump's 2009 Book Warning On Dangers Of Email Comes Back To Haunt Her
# 2000
# Top GOP Senator Says Texas Is 'No Longer A Reliably Red State'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Montana Inmate Claims Religious Right To Smoke Pot In Jail
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump May Move Ahead With Plans To Make Asylum Seekers Wait In Mexico: Report
# 620
# White House Lashed For 'Burying' Bombshell Climate Report With Holiday Release
# 370
# GOP Senator John Kennedy Opts Against Gubernatorial Run In Louisiana
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Democrats Are Divided On The Ideological Future Of Their Party
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Democrats Fall Short Of Ousting New Hampshire Secretary of State
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Christians Decry Trump Administration After Children Are Tear-Gassed At Border
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Elizabeth Warren Brings Her Anti-Corruption Message In Major Foreign Policy Speech
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Many Americans Are Giving Trump The Benefit Of The Doubt On Manufacturing Jobs
# 950
# 400 Justice Department Alumni Are 'Disturbed' Over Whitaker Appointment
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Rants About Khashoggi, Judges, Borders In Thanksgiving Call With Troops
# 3900
# Meghan McCain Says Paul Manafort Should 'Rot In Hell'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Lindsey Graham Accuses Alexandria Ocasio-Cortez Of Comparing Refugee Caravan To Holocaust
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# James Comey Responds To Subpoena From Republicans: 'Let's Invite Everyone To See'
# 3800
# Senator Chuck Grassley Neglects Juveniles For Crime Reform Bill, Advocates Say
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Sen. Jeff Merkley Targets Big Pharma With Bill To Lower Prescription Drug Prices
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump's 'Very High Levels Of Intelligence' Draw Some Doubt On Twitter
# 2600
# ______________________________
# In First-Of-Its-Kind Lawsuit, Baltimore Sues Trump Over Immigrants' Access To Benefits
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Congressman Calls For Hearing Into North Carolina Election Fraud Reports
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# The Wisconsin Senate's Move To Undermine An Incoming Democratic Governor, Explained
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Contradicting Trump, Incoming Mexico Government Denies Making Deal To Host Asylum-Seekers
# 420
# George H.W. Bush's Life Remembered In Photographs
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# GOP Rep. Thomas Massie Tries To Criticize Free Health Care, Stumbles On Good Idea Instead
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Jeff Sessions Jokes About Getting Fired: My 'Pink Slip' Was 'More Public Than Most'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Originator Of The Trump Penthouse For Putin Idea Says He Doesn't Know How Far It Went
# 100
# Michelle Obama Cancels Two Book Tour Events To Attend George H.W. Bush's Funeral
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Mexico Swears In First Leftist President In 70 Years
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Avoids Visiting Troops In Harm’s Way, Talks To Them From His Country Club Instead
# 4600
# Dove Wrangler Arrested With Arsenal Of Guns, Nazi Flags Has Odd ‘Bachelor’ Connection
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# One School's Mission To Teach Kids Whose Lives Have Been Hijacked By Trauma
# 210
# Coal Consumption In The U.S. Falls To Lowest Level Since 1979
# 230
# GOP Rep. Chris Stewart On Khashoggi Killing: 'Journalists Disappear All Over The Country'
# 470
# Wisconsin Gov.-Elect Tony Evers Will Ask Scott Walker To Veto GOP Power Grab
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Democrats Only Need 1 More GOP Vote To Sink A Controversial Judicial Nominee
# 660
# Justice Department Awards $16 Million To Las Vegas Concert Shooting Victims
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Michelle Obama's Memoir Tops The Charts: 'Becoming' Is 2018's Bestselling Book
# 4400
# Donald Trump, Xi Jinping Agree To Trade Truce At G-20 Summit
# 300
# ______________________________
# Donald Trump's Thanksgiving Turkey Pardoning Gets Roasted On Twitter
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Don Lemon Gives Blistering Review Of Donald Trump's G20 Performance: 'Weak, Weak, Weak'
# 2300
# No, Trump's Migrant Child Separation Policy Isn't The 'Exact Same' As Obama's
# 1600
# George H.W. Bush Funeral Details Released
# 120
# Undocumented Man Arrested After Leaving Church For Immigration Appointment
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Lawsuit Urges Court To Make Blake Farenthold's Employer Stop Paying Him
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Twitter Erupts Over Donald Trump's Low Oil Price 'Thank You' To Saudi Arabia
# 3500
# CIA Director Gina Haspel Absent During Hearing On Saudi Arabia, Khashoggi Killing
# 620
# Clintons Weigh In On Trump’s Feud With Adm. McRaven In First Tour Stop
# 390
# In The Trump Era, Democrats Look More Kindly On Past GOP Presidents
# 270
# Trump Says China Has Agreed To 'Reduce And Remove Tariffs' On American-Made Cars
# 310
# Obama Comments On Death Of 'Patriot And Humble Servant' George H.W. Bush
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Says He Hired Michael Cohen As His Lawyer Because Of A 'Favor'
# 1400
# BMW Fact-Checks Trump On ‘Major New Plant,’ Which Hasn't Been Finalized
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Asylum Seekers Would Stay In Mexico Under New Deal Cut By Trump: Report
# 170
# Election Fraud Hearing Could Change Outcome Of North Carolina Vote
# 1200
# Trump Aides Caught In Web Of Lies Over Russia Contacts
# 750
# The Trump Administration Just Made It Easier For States To Rewrite Obamacare Rules
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Chief Justice John Roberts Criticizes Trump For ‘Obama Judge’ Asylum Comment
# 4200
# Colorado Boy Convinces Town To Overturn Ban On Snowball Fights
# 590
# ______________________________
# Former GOP Candidate Whose Pipe Bomb Injured Postal Worker Reaches Plea Deal
# 200
# Despite A Big Setback, Progressives Increase Their Leadership Clout In New Congress
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Here’s Everything You Need To Know About Michael Cohen’s New Guilty Plea
# 350
# It's No Surprise Who Donald Trump Thinks Should Be Time's 2018 'Person Of The Year'
# 1200
# The Proud Boys Are Imploding
# 7800
# Ford Is Still Receiving Death Threats, Kavanaugh Is Back To Coaching Basketball
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Refuses To Say Whether He Regrets Attacking The Bush Family
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Kavanaugh And Gorsuch Confirmations Force Progressives To Rethink The Supreme Court
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Alexandria Ocasio-Cortez Dishes It Right Back To Lindsey Graham In Twitter Tiff
# 3800
# U.S. Supreme Court Justices Pose For 2018 Class Photo, Twitter Users Chime In
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Twitter Users Burn Rick Santorum For Saying Climate Scientists 'Driven By Money'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Is Ohio Cracking Down On Kratom? Here's What We Know So Far.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Michael Moore Rips Donald Trump: He 'Doesn't Understand' How General Motors Played Him
# 3500
# Paul Manafort’s Lawyer Told Trump Team What His Client Said To Mueller: Report
# 1900
# North Carolina Delays Certifying Results Of Congressional Race Amid Probe Of Irregularities
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Wisconsin Republicans To Vote On Weakening Governor's Power
# 410
# ICE To Release Asylum-Seeker After 2 Years In Detention
# 240
# California Takes Its Time Counting Ballots. Paul Ryan Thinks That's Really Weird.
# 120
# Parkland Dad Praises George H.W. Bush For His Rejection Of The NRA
# 1000
# If Trump Thinks Michael Cohen’s Plea Is Bad, Wait Till Dems Run The House Intel Committee
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# ______________________________
# Christine Blasey Ford: 'I Am Grateful To Have Had The Opportunity To Fulfill My Civic Duty'
# 370
# A Letter That George H.W. Bush Wrote To Bill Clinton Is Going Viral Again
# 1100
# Michelle Obama Shades Donald Trump While Talking About White House Morals
# 2100
# Saudi-Funded Lobbyists Paid For 500 Nights At Trump D.C. Hotel Right After Election
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Alexandria Ocasio-Cortez Demands 'Living Wage' For Hill Workers
# 2000
# Migrant Mother Impaled In Front Of Children While Attempting To Scale Border Fence
# 850
# Joe Biden Says He's 'The Most Qualified Person In The Country To Be President'
# 8700
# Ron Johnson Dismisses Uproar Over Wisconsin GOP Power Grab As 'Way Overblown'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Mike Pence Honors World AIDS Day After Fueling HIV Outbreak In His State
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Says He Looks Like Elvis And Twitter Users Get All Shook Up
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Former President George H.W. Bush Dead At Age 94
# 25000
# Trump: Michael Cohen Should Serve ‘Complete Sentence' For Things 'Unrelated' To Campaign
# 1400
# In The Closet In The White House: The Tortured History Of The Gay Man Who Touched Off The Purge Of Gays In Government
# 380
# This Woman Got 8 Years In Prison For Illegal Voting. Texas Is Showing No Mercy.
# 2000
# Melania Trump's Red Christmas Trees Conjure 'Handmaid's Tale' For Twitter Users
# 8000
# Melania Trump Thinks White House's Red Christmas Trees 'Look Fantastic'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Shares Meme Showing Obama, Clintons Behind Bars For Treason
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Kamala Harris To Decide On 2020 White House Run 'Over The Holiday'
# 3300
# This Thanksgiving, The Trump Administration Is Taking Land From The Tribe That Welcomed The Pilgrims
# 140
# Ford Is Still Receiving Death Threats, Kavanaugh Is Back To Coaching Basketball
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# ______________________________
# Texas Camp For Teen Migrants Bypasses Safety Regulations
# 840
# The GM Layoffs Sure Look Like A Broken Trump Promise
# 4500
# Methodist Church Sign Subtly Criticizes U.S. Use Of Tear Gas At The Border
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump’s Wall Shutdown Would Leave Border Patrol, ICE, Other DHS Employees In Lurch
# 350
# Alexandria Ocasio-Cortez Burns Fox News On Twitter For Being 'Obsessed' With Her
# 2500
# How Trump's Labor Secretary Covered For A Millionaire Sex Abuser
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Once Mocked The Same George H.W. Bush Quote He Used To Remember Him
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# This Woman Got 8 Years In Prison For Illegal Voting. Texas Is Showing No Mercy.
# 2000
# Melania Trump's Red Christmas Trees Conjure 'Handmaid's Tale' For Twitter Users
# 8000
# Melania Trump Thinks White House's Red Christmas Trees 'Look Fantastic'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Donald Trump Shares Meme Showing Obama, Clintons Behind Bars For Treason
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# President Trump Says He's Too Intelligent To Believe In Climate Change
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Hakeem Jeffries Wins Contested House Democratic Caucus Chair Race
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Alexandria Ocasio-Cortez Shuts Down Ex-Trump Aide Sebastian Gorka
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Hemp Is Finally About To Go Fully Legit In The U.S.
# 1400
# Kamala Harris To Decide On 2020 White House Run 'Over The Holiday'
# 3300
# Here’s Everything You Need To Know About Michael Cohen’s New Guilty Plea
# 350
# It's No Surprise Who Donald Trump Thinks Should Be Time's 2018 'Person Of The Year'
# 1200
# The Proud Boys Are Imploding
# 7800
# Mueller: Paul Manafort Broke Plea Deal By Lying To Investigators In Russia Probe
# 660
# ______________________________
# China Is Using U.S. 'War On Terror' Rhetoric To Justify Detaining 1 Million People
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Jon Tester Was Donald Trump’s Top Target. Here’s How He Survived.
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Nooses Hung At Mississippi State Capitol Just Before Runoff Election (UPDATE)
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Racist Arizona Lawmaker Says Black People 'Don't Blend In'
# 6500
# Alexandria Ocasio-Cortez Throws Support Behind Nancy Pelosi For House Speaker
# 1700
# Trump's Border Chief Knocks Down President's Claim About 'Minor Form' Of Tear Gas
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Sully The Service Dog Arrives To View Owner George H.W. Bush's Casket
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Deval Patrick Says He Won't Run For President In 2020
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Scientists Slam Trump's Clueless Climate Change Tweet: 'He's A Clown'
# 11000
# Tom Cotton Is Here To Ruin Prison Reform
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Progressive Lawmakers Hold Health Care Rally Outside Centrist Harvard Conference
# 220
# Internet Users Are Finding Creative Ways To Mess With Giuliani's Old Tweets
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Trump Falsely Claims Border Agents Were Badly Hurt In Migrant Tear Gas Clashes
# 7200
# U.S. Border Patrol Launches Tear Gas At Migrants Over Attempt To Breach Fence
# 16000
# 'Generous American Patriot': World Leaders Pay Tribute To George H.W. Bush
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Sarah Huckabee Sanders Gets Fact-Checked Live On Air By CNN
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Alexandria Ocasio-Cortez Burns Fox News On Twitter For Being 'Obsessed' With Her
# 2500
# Donald Trump Once Mocked The Same George H.W. Bush Quote He Used To Remember Him
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# Senate To Vote On Trump Judicial Pick Who Critics Call The 'Vote-Suppressor-In-Chief'
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'
# U.S. Supreme Court Justices Pose For 2018 Class Photo, Twitter Users Chime In
# Error on line 36 AttributeError 'NoneType' object has no attribute 'text'

# %%
articlesDF = pd.DataFrame(dfs[0])
wordsDF = pd.DataFrame(dfs[1])
articlesDF = articlesDF[['url', 'articleTitle', 'socialMediaCount']]
articlesDF = articlesDF.sort_values('socialMediaCount', ascending=False)
wordsDF = wordsDF[['articleTitle', 'word', 'socialMediaCount']]

wordsDF = wordsDF[wordsDF.word != 'to']
wordsDF = wordsDF[wordsDF.word != 'in']
wordsDF = wordsDF[wordsDF.word != 'for']
wordsDF = wordsDF[wordsDF.word != 'of']
wordsDF = wordsDF[wordsDF.word != 'on']
wordsDF = wordsDF[wordsDF.word != 'a']
wordsDF = wordsDF[wordsDF.word != 'at']
wordsDF = wordsDF[wordsDF.word != 'be']
wordsDF = wordsDF[wordsDF.word != 'the']
wordsDF = wordsDF[wordsDF.word != 'with']
wordsDF = wordsDF[wordsDF.word != 'by']
wordsDF = wordsDF[wordsDF.word != 'from']
wordsDF = wordsDF[wordsDF.word != 'is']
wordsDF = wordsDF[wordsDF.word != 'about']
wordsDF = wordsDF[wordsDF.word != 'as']
wordsDF = wordsDF[wordsDF.word != 'over']
wordsDF = wordsDF[wordsDF.word != 'team']
wordsDF = wordsDF[wordsDF.word != 'out']
wordsDF = wordsDF[wordsDF.word != 'they']
wordsDF = wordsDF[wordsDF.word != 'that']
wordsDF = wordsDF[wordsDF.word != 'over']
wordsDF = wordsDF[wordsDF.word != 'end']
wordsDF = wordsDF[wordsDF.word != 'wants']
wordsDF = wordsDF[wordsDF.word != 'called']
wordsDF = wordsDF[wordsDF.word != 'calls']
wordsDF = wordsDF[wordsDF.word != 'over']
wordsDF = wordsDF[wordsDF.word != '$$']
wordsDF = wordsDF[wordsDF.word != 'foundation']
wordsDF = wordsDF[wordsDF.word != 'have']
wordsDF = wordsDF[wordsDF.word != '9th']
wordsDF = wordsDF[wordsDF.word != 'into']
wordsDF = wordsDF[wordsDF.word != 'after']
wordsDF = wordsDF[wordsDF.word != 'key']
wordsDF = wordsDF[wordsDF.word != 'among']
wordsDF = wordsDF[wordsDF.word != 'could']
wordsDF = wordsDF[wordsDF.word != 'says']
wordsDF = wordsDF[wordsDF.word != 'has']
wordsDF = wordsDF[wordsDF.word != 'him']
wordsDF = wordsDF[wordsDF.word != 'new']
wordsDF = wordsDF[wordsDF.word != 'he']
wordsDF = wordsDF[wordsDF.word != 'more']
wordsDF = wordsDF[wordsDF.word != 'us']
wordsDF = wordsDF[wordsDF.word != 'its']
wordsDF = wordsDF[wordsDF.word != 'no']
wordsDF = wordsDF[wordsDF.word != 'are']
wordsDF = wordsDF[wordsDF.word != 'his']
wordsDF = wordsDF[wordsDF.word != 'and']
wordsDF = wordsDF[wordsDF.word != 'back']
wordsDF = wordsDF[wordsDF.word != 'this']
wordsDF = wordsDF[wordsDF.word != 'need']
wordsDF = wordsDF[wordsDF.word != 'know']
wordsDF = wordsDF[wordsDF.word != 'doesnt']
wordsDF = wordsDF[wordsDF.word != 'will']
wordsDF = wordsDF[wordsDF.word != 'not']
wordsDF = wordsDF[wordsDF.word != 'who']
wordsDF = wordsDF[wordsDF.word != 'hes']
wordsDF = wordsDF[wordsDF.word != 'up']
wordsDF = wordsDF[wordsDF.word != '1']

# %%
#get word counts DF
wordCounts = wordsDF['word'].value_counts()
wordCountsDF = pd.DataFrame(wordCounts, columns= ['word'])
wordCountsDF = wordCountsDF.reset_index()
wordCountsDF.columns = ['word', 'articleAppearanceCount']

# %%
#getting average comments per word 
averageInteractsPerWord = wordsDF.groupby('word', as_index=False)['socialMediaCount'].mean()
only1 = wordCounts[wordCounts == 1]
for word in only1.index:
    averageInteractsPerWord = averageInteractsPerWord[averageInteractsPerWord.word != word]
        
averageInteractsPerWord = averageInteractsPerWord.sort_values('socialMediaCount', ascending=False)

# %%
#getting occurance of word counts in titles

wordCountAvgSocialMedia = []
for title in articlesDF['articleTitle']:
    socialMediaCount = articlesDF.loc[articlesDF['articleTitle'] == title, 'socialMediaCount'].iloc[0]
    wordsInTitle = title.split()
    wordCount = len(wordsInTitle)
    wordCountAvgSocialMedia.append({'wordCount': wordCount, 'socialMediaCount': socialMediaCount})

wordCountAvgSocialMediaAllLengths = pd.DataFrame(wordCountAvgSocialMedia)


wordCountAvgSocialMedia = wordCountAvgSocialMediaAllLengths.groupby('wordCount', as_index=False)['socialMediaCount'].mean()

        

wordCountAvgSocialMedia['socialMediaCount'] = round(wordCountAvgSocialMedia['socialMediaCount'], 2)
wordCountAvgSocialMedia = wordCountAvgSocialMedia.sort_values('socialMediaCount', ascending=False)

counts = []
for count in wordCountAvgSocialMedia['wordCount']:
    totalArticlesWithLength = 0
    for count2 in wordCountAvgSocialMediaAllLengths['wordCount']:
        if count == count2:
            totalArticlesWithLength += 1
    counts.append({'wordCount':count, 'totalCount': totalArticlesWithLength})
    
counts = pd.DataFrame(counts)
wordCountAvgSocialMedia = pd.merge(counts, wordCountAvgSocialMedia, on='wordCount')
wordCountAvgSocialMedia['socialMediaCount'] = round(wordCountAvgSocialMedia['socialMediaCount'], 2)
wordCountAvgSocialMedia.columns = ['totalArticlesWithTitleCount', 'wordCountInTitle', 'averageSocialMediaCount']
wordCountAvgSocialMedia
# Out:
#     totalArticlesWithTitleCount  wordCountInTitle  averageSocialMediaCount
# 0                             2                 5                  7800.00
# 1                             8                 9                  5136.25
# 2                            24                11                  3859.17
# 3                            31                12                  3057.74
# 4                            16                10                  2604.38
# 5                             8                14                  2171.25
# 6                            29                13                  2063.45
# 7                             9                15                  1550.00
# 8                             2                 6                  1160.00
# 9                             6                 8                   776.67
# 10                            1                 7                   540.00
# 11                            1                23                   380.00
# 12                            3                16                   236.67

# %%
articlesDF.describe()
#average number of interactions: 2753.86
#minimum interactions: cannot do as any article with less than 100 interactions did not show any value
#maximum interactions: 35,000 (Trump Appoints State Department’s Heather Nauert As U.S. Ambassador To United Nations)
# Out:
#        socialMediaCount
# count        140.000000
# mean        2753.857143
# std         4603.161658
# min          100.000000
# 25%          407.500000
# 50%         1100.000000
# 75%         3350.000000
# max        35000.000000

# %%
wordCountsDF.describe()
#average appearance for a word over all articles: 1.51
#Most appearance for word: 58 (Trump)
# Out:
#        articleAppearanceCount
# count              826.000000
# mean                 1.508475
# std                  2.254273
# min                  1.000000
# 25%                  1.000000
# 50%                  1.000000
# 75%                  1.000000
# max                 58.000000

# %%
averageInteractsPerWord.describe()
#averageCommentsPerWord
#NOTE: remove any words that only appeared in 1 article (to remove bias)
#Most average comment count: 11,600 (gas)
#Least average comment count (for word with some political connection): 205 (asylum-seeker)
#average average comment count: 2794.1
# Out:
#        socialMediaCount
# count         197.00000
# mean         2794.10037
# std          2599.02266
# min           125.00000
# 25%           840.00000
# 50%          2020.00000
# 75%          3500.00000
# max         11600.00000

# %%
wordCountAvgSocialMedia.describe()
#high number of words in title: 23
#low number of words in title: 5
#there seems to be no correlation between word count in title and social mediaCount for that article
# Out:
#        totalArticlesWithTitleCount  wordCountInTitle  averageSocialMediaCount
# count                    13.000000         13.000000                13.000000
# mean                     10.769231         11.461538              2410.429231
# std                      10.763781          4.892433              2170.447529
# min                       1.000000          5.000000               236.670000
# 25%                       2.000000          8.000000               776.670000
# 50%                       8.000000         11.000000              2063.450000
# 75%                      16.000000         14.000000              3057.740000
# max                      31.000000         23.000000              7800.000000
